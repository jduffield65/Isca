# %%
import xarray as xr
import zipfile

# %%
input_file = '/Users/joshduffield/Desktop/skt.nc'

# %%
ds = xr.load_dataset(input_file).t

# %%
ds
# Out:
# <xarray.DataArray 't' (time: 31, latitude: 721, longitude: 1440)> Size: 129MB
# array([[[245.93974, 245.93974, 245.93974, ..., 245.93974, 245.93974,
#          245.93974],
#         [246.01152, 246.01111, 246.01064, ..., 246.0128 , 246.01233,
#          246.01193],
#         [246.2718 , 246.27034, 246.26866, ..., 246.27628, 246.2748 ,
#          246.27336],
#         ...,
#         [244.63889, 244.63943, 244.63992, ..., 244.63737, 244.63779,
#          244.63835],
#         [244.48477, 244.48505, 244.48524, ..., 244.48404, 244.4843 ,
#          244.48453],
#         [244.01689, 244.01689, 244.01689, ..., 244.01689, 244.01689,
#          244.01689]],
#
#        [[245.78403, 245.78403, 245.78403, ..., 245.78403, 245.78403,
#          245.78403],
#         [245.85133, 245.85081, 245.85025, ..., 245.8529 , 245.85233,
#          245.85184],
#         [246.1035 , 246.1018 , 246.0999 , ..., 246.10861, 246.10693,
#          246.10527],
# ...
# ...

# %%
ds.isel(latitude=0, longitude=0).plot()
