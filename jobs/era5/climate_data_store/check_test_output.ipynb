# %%
import xarray as xr

# %%
output_dir = '/Users/joshduffield/Desktop/test/'
for year in range(1979, 1983):
    ds = xr.load_dataset(f'/Users/joshduffield/Desktop/test/{year}.nc')
    print(year, f"{str(ds.valid_time[0].values)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/Isca/lib/python3.9/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File ~/miniforge3/envs/Isca/lib/python3.9/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Users/joshduffield/Desktop/test/1979.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '18645bb8-df4c-4b43-adc4-a4437ea0149e']
#
# During handling of the above exception, another exception occurred:
#
# ...
