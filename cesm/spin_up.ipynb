# %%
import xarray as xr
import numpy as np
from isca_tools import cesm
# Out:
# 2024-09-20 16:03:12,895 - isca - WARNING - Environment variable GFDL_SOC not set, but this is only required if using SocratesCodebase. Setting to None

# %%
input_dir = '/Users/joshduffield/Desktop/'
exp_name = 'e.e20.E1850TEST.f09_g17.test'
ds = cesm.load_dataset(exp_name, archive_dir=input_dir)
# Out:
# <xarray.Dataset> Size: 6kB
# Dimensions:  (time: 2, lat: 192, ilev: 33)
# Coordinates:
#   * lat      (lat) float64 2kB -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * ilev     (ilev) float64 264B 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * time     (time) object 16B 0001-02-01 00:00:00 0001-03-01 00:00:00
# Data variables:
#     gw       (time, lat) float64 3kB dask.array<chunksize=(1, 192), meta=np.ndarray>
#     hybi     (time, ilev) float64 528B dask.array<chunksize=(1, 33), meta=np.ndarray>
#     hyai     (time, ilev) float64 528B dask.array<chunksize=(1, 33), meta=np.ndarray>
#     P0       (time) float64 16B 1e+05 1e+05
# Attributes:
#     Conventions:       CF-1.0
#     source:            CAM
#     case:              e.e20.E1850TEST.f09_g17.test
#     logname:           jamd
#     host:              ln02
#     initial_file:      /work/n02/n02/jamd/cesm/CESM2.1.3/cesm_inputdata/atm/c...
# ...
