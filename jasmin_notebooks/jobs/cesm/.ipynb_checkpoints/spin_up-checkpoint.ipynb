# %%
import xarray as xr
import numpy as np
from isca_tools import cesm
from isca_tools.utils import area_weighting
from isca_tools.utils import print_ds_var_list
# Out:
# 2024-09-24 15:04:45,658 - isca - WARNING - Environment variable GFDL_SOC not set, but this is only required if using SocratesCodebase. Setting to None

# %%
input_dir = '/Users/joshduffield/Desktop/'
exp_name = 'e.e20.E1850TEST.f09_g17.test'
var_keep = ['TS', 'FSNTOA', 'FLNT']
ds = cesm.load_dataset(exp_name, archive_dir=input_dir)[var_keep]

# %% [markdown]
# ## Plot global mean Surface Temperature

# %%
area_weighting(ds.TS).mean(dim=['lat', 'lon']).plot()

# %% [markdown]
# ## Plot global mean TOA flux inbalance

# %%
area_weighting(ds.FSNTOA-ds.FLNT).mean(dim=['lon', 'lat']).plot()

# %%
for i in ds.variables:
    try:
        if 'top of' not in ds[i].long_name.lower():
            continue
        print(i, ds[i].long_name)
    except AttributeError:
        continue
# Out:
# FSNTOA Net solar flux at top of atmosphere
# FLNT Net longwave flux at top of model

# %%
'TS'.capitalize()
# Out:
# 'Ts'

# %%
ds[i].long_name
# Out:
# 'time'

# %%
ds[i]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 ds[i]
#
# NameError: name 'i' is not defined

# %%
ds.variables
# Out:
# Frozen({'gw': <xarray.Variable (time: 2, lat: 192)> Size: 3kB
# dask.array<concatenate, shape=(2, 192), dtype=float64, chunksize=(1, 192), chunktype=numpy.ndarray>
# Attributes:
#     long_name:  latitude weights, 'hyam': <xarray.Variable (time: 2, lev: 32)> Size: 512B
# dask.array<concatenate, shape=(2, 32), dtype=float64, chunksize=(1, 32), chunktype=numpy.ndarray>
# Attributes:
#     long_name:  hybrid A coefficient at layer midpoints, 'hybm': <xarray.Variable (time: 2, lev: 32)> Size: 512B
# dask.array<concatenate, shape=(2, 32), dtype=float64, chunksize=(1, 32), chunktype=numpy.ndarray>
# Attributes:
#     long_name:  hybrid B coefficient at layer midpoints, 'P0': <xarray.Variable (time: 2)> Size: 16B
# array([100000., 100000.])
# Attributes:
#     long_name:  reference pressure
#     units:      Pa, 'hyai': <xarray.Variable (time: 2, ilev: 33)> Size: 528B
# dask.array<concatenate, shape=(2, 33), dtype=float64, chunksize=(1, 33), chunktype=numpy.ndarray>
# Attributes:
# ...
